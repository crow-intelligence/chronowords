# %%
import json

with open("../data/speeches_lemmatized.json") as f:
    speeches = json.load(f)

# %% [markdown]
# # Preprocessing the corpus

# %%
from collections import defaultdict
from datetime import datetime

def group_speeches_by_quarter_century(speeches_list):
    """
    Group speeches into quarter centuries and create text files.

    Args:
        speeches_list: List of dictionaries containing speech data

    Returns:
        Dictionary with quarter century ranges as keys and filenames as values
    """
    # Group speeches by quarter century
    quarter_groups = defaultdict(list)

    for speech in speeches_list:
        year = int(speech['date'][:4])  # Get year from date
        # Calculate quarter century (1800-1824, 1825-1849, etc.)
        quarter_start = year - (year % 25)
        quarter_end = quarter_start + 24
        quarter_key = f"{quarter_start}-{quarter_end}"

        quarter_groups[quarter_key].append(speech)

    # Create text files for each quarter century
    file_paths = {}
    for quarter, speeches in quarter_groups.items():
        # Sort speeches by date
        speeches.sort(key=lambda x: x['date'])

        # Create lemmatized version
        lemma_text = "\n".join(s['lemmatized'] for s in speeches)
        lemma_filename = f"../data/speeches_{quarter}_lemmatized.txt"
        with open(lemma_filename, 'w', encoding='utf-8') as f:
            f.write(lemma_text)

        # Create transcript version
        transcript_text = "\n".join(s['transcript'] for s in speeches)
        transcript_filename = f"../data/speeches_{quarter}_transcript.txt"
        with open(transcript_filename, 'w', encoding='utf-8') as f:
            f.write(transcript_text)

        file_paths[quarter] = {
            'lemmatized': lemma_filename,
            'transcript': transcript_filename,
            'count': len(speeches)
        }

    # Print summary
    print("Quarter Century Statistics:")
    for quarter, info in file_paths.items():
        print(f"{quarter}: {info['count']} speeches")

    return file_paths


file_paths = group_speeches_by_quarter_century(speeches)
# Out:
# Quarter Century Statistics:
# 1800-1824: 59 speeches
# 1900-1924: 91 speeches
# 1975-1999: 150 speeches
# 1825-1849: 90 speeches
# 2000-2024: 164 speeches
# 1950-1974: 165 speeches
# 1925-1949: 103 speeches
# 1875-1899: 99 speeches
# 1775-1799: 28 speeches
# 1850-1874: 108 speeches
# 2025-2049: 1 speeches

# %% [markdown]
# # Building language models

# %%
from chronowords.algebra.svd import SVDAlgebra
from pathlib import Path

def create_embeddings_for_periods(file_paths, use_lemmatized=True):
    """
    Create word embeddings for each quarter-century period.

    Args:
        file_paths: Dictionary from group_speeches_by_quarter_century
        use_lemmatized: Whether to use lemmatized or transcript texts

    Returns:
        Dictionary of {period: SVDAlgebra model}
    """
    models = {}

    for period, info in file_paths.items():
        print(f"\nProcessing period {period}")

        # Choose which text version to use
        filename = info['lemmatized' if use_lemmatized else 'transcript']

        # Create generator for the corpus
        def read_corpus():
            with open(filename, 'r', encoding='utf-8') as f:
                for line in f:
                    if line.strip():  # Skip empty lines
                        yield line.strip().lower()  # Lowercase everything

        # Initialize and train model
        model = SVDAlgebra(
            n_components=100,     # Smaller dimension for historical texts
            window_size=5,
            min_word_length=3,
            cms_width=1_000_000,  # 1M width should be enough for this corpus
            cms_depth=5
        )

        try:
            # Train model
            print(f"Training model for {period}...")
            model.train(read_corpus())

            # Print some statistics
            print(f"Vocabulary size: {len(model.vocabulary)}")
            print(f"Sample words: {model.vocabulary[:10]}")

            models[period] = model

        except Exception as e:
            print(f"Error processing period {period}: {str(e)}")

    return models

# Create models for both lemmatized and transcript versions
print("Creating models for lemmatized texts...")
lemma_models = create_embeddings_for_periods(file_paths, use_lemmatized=True)

print("\nCreating models for transcript texts...")
transcript_models = create_embeddings_for_periods(file_paths, use_lemmatized=False)

# Save models for later use
for period, model in lemma_models.items():
    save_path = Path(f"../models/lemmatized/{period}")
    save_path.mkdir(parents=True, exist_ok=True)
    model.save_model(save_path)

for period, model in transcript_models.items():
    save_path = Path(f"../models/transcript/{period}")
    save_path.mkdir(parents=True, exist_ok=True)
    model.save_model(save_path)
# Out:
# Creating models for lemmatized texts...
#
# Processing period 1800-1824
# Training model for 1800-1824...
# Counting words and skipgrams...
# Total words: 97700
# Total skipgrams: 584554
# Building vocabulary...
# Vocabulary size: 1331
# Computing PPMI matrix...
# PPMI matrix shape: (1331, 1331)
# PPMI matrix non-zeros: 0
# Computing SVD...
# Singular values: [7.27026383e-09 7.23292930e-09 7.18736310e-09 7.16579320e-09
#  7.14742474e-09 7.13339457e-09 7.10757300e-09 7.10055834e-09
#  7.07637587e-09 7.06131469e-09]
# Final embeddings shape: (1331, 100)
# Embeddings non-zeros: 133100
# Min norm: 1.7573036827643673e-05
# Max norm: 2.8281866194714123e-05
# Mean norm: 2.221218214258625e-05
# Vocabulary size: 1331
# Sample words: ['the', 'and', 'have', 'that', 'which', 'our', 'with', 'for', 'they', 'their']
#
# Processing period 1900-1924
# Training model for 1900-1924...
# Counting words and skipgrams...
# Total words: 360878
# Total skipgrams: 2120636
# Building vocabulary...
# Vocabulary size: 1383
# Computing PPMI matrix...
# PPMI matrix shape: (1383, 1383)
# PPMI matrix non-zeros: 840
# Computing SVD...
# Singular values: [157.61557346  47.75076281  45.12706885  44.60070728  42.31504097
#   39.98803175  39.43152273  38.83466439  36.91169775  35.6666726 ]
# Final embeddings shape: (1383, 100)
# Embeddings non-zeros: 138300
# Min norm: 9.745542788039096e-06
# Max norm: 6.2996534722068835
# Mean norm: 0.198250769811962
# Vocabulary size: 1383
# Sample words: ['the', 'and', 'have', 'that', 'for', 'which', 'with', 'not', 'this', 'our']
#
# Processing period 1975-1999
# Training model for 1975-1999...
# Counting words and skipgrams...
# Total words: 454187
# Total skipgrams: 2535938
# Building vocabulary...
# Vocabulary size: 1190
# Computing PPMI matrix...
# PPMI matrix shape: (1190, 1190)
# PPMI matrix non-zeros: 1455
# Computing SVD...
# Singular values: [234.15960312  57.47917336  55.96991846  49.89754783  49.23748282
#   48.5115538   46.9107785   45.04527371  42.08763127  41.82192405]
# Final embeddings shape: (1190, 100)
# Embeddings non-zeros: 119000
# Min norm: 8.763961799945689e-06
# Max norm: 6.59585137655777
# Mean norm: 0.2941252938889402
# Vocabulary size: 1190
# Sample words: ['the', 'and', 'that', 'have', 'our', 'for', 'not', 'this', 'you', 'will']
#
# Processing period 1825-1849
# Training model for 1825-1849...
# Counting words and skipgrams...
# Total words: 341041
# Total skipgrams: 2006019
# Building vocabulary...
# Vocabulary size: 1298
# Computing PPMI matrix...
# PPMI matrix shape: (1298, 1298)
# PPMI matrix non-zeros: 544
# Computing SVD...
# Singular values: [133.91475104  44.70308252  37.8349263   36.99576537  35.38563159
#   34.52592203  32.12911196  30.8184857   29.8577218   29.34327341]
# Final embeddings shape: (1298, 100)
# Embeddings non-zeros: 129800
# Min norm: 1.1106074394018388e-05
# Max norm: 6.161694718823772
# Mean norm: 0.15978098467706398
# Vocabulary size: 1298
# Sample words: ['the', 'and', 'have', 'that', 'which', 'for', 'with', 'our', 'they', 'not']
#
# Processing period 2000-2024
# Training model for 2000-2024...
# Counting words and skipgrams...
# Total words: 508620
# Total skipgrams: 2774564
# Building vocabulary...
# Vocabulary size: 1188
# Computing PPMI matrix...
# PPMI matrix shape: (1188, 1188)
# PPMI matrix non-zeros: 2391
# Computing SVD...
# Singular values: [323.82616694  65.54843264  61.45400862  58.60465536  56.51144268
#   56.19801624  54.79240208  53.16252318  52.79898239  52.07326565]
# Final embeddings shape: (1188, 100)
# Embeddings non-zeros: 118800
# Min norm: 4.932868812461127e-06
# Max norm: 6.586708119473039
# Mean norm: 0.37045715894774484
# Vocabulary size: 1188
# Sample words: ['the', 'and', 'that', 'have', 'you', 'our', 'they', 'for', 'not', 'this']
#
# Processing period 1950-1974
# Training model for 1950-1974...
# Counting words and skipgrams...
# Total words: 437734
# Total skipgrams: 2402121
# Building vocabulary...
# Vocabulary size: 1255
# Computing PPMI matrix...
# PPMI matrix shape: (1255, 1255)
# PPMI matrix non-zeros: 1010
# Computing SVD...
# Singular values: [198.36229084  54.80831864  47.95853815  47.28640783  45.07248816
#   42.90031137  42.24697798  40.70426124  38.63533591  37.15899985]
# Final embeddings shape: (1255, 100)
# Embeddings non-zeros: 125500
# Min norm: 9.839360398861337e-06
# Max norm: 6.491934652576284
# Mean norm: 0.22806785996846318
# Vocabulary size: 1255
# Sample words: ['the', 'and', 'that', 'have', 'our', 'for', 'this', 'not', 'will', 'they']
#
# Processing period 1925-1949
# Training model for 1925-1949...
# Counting words and skipgrams...
# Total words: 235563
# Total skipgrams: 1322305
# Building vocabulary...
# Vocabulary size: 1305
# Computing PPMI matrix...
# PPMI matrix shape: (1305, 1305)
# PPMI matrix non-zeros: 23
# Computing SVD...
# Singular values: [24.72063233 15.25331523 13.53789898  9.65045634  8.24529412  8.24529412
#   8.18989891  7.55214694  7.55214694  5.74826926]
# Final embeddings shape: (1305, 100)
# Embeddings non-zeros: 130500
# Min norm: 1.622528134565929e-05
# Max norm: 4.290810619681117
# Mean norm: 0.02707505086338355
# Vocabulary size: 1305
# Sample words: ['the', 'and', 'have', 'that', 'our', 'for', 'this', 'not', 'they', 'which']
#
# Processing period 1875-1899
# Training model for 1875-1899...
# Counting words and skipgrams...
# Total words: 390323
# Total skipgrams: 2287530
# Building vocabulary...
# Vocabulary size: 1361
# Computing PPMI matrix...
# PPMI matrix shape: (1361, 1361)
# PPMI matrix non-zeros: 748
# Computing SVD...
# Singular values: [150.02471548  51.18066221  45.6938156   43.30092069  41.27509534
#   40.61603331  37.83433986  37.43698732  36.2963339   33.99858881]
# Final embeddings shape: (1361, 100)
# Embeddings non-zeros: 136100
# Min norm: 9.345109714479822e-06
# Max norm: 6.9537768840445295
# Mean norm: 0.19418600592305982
# Vocabulary size: 1361
# Sample words: ['the', 'and', 'have', 'that', 'for', 'which', 'our', 'this', 'with', 'not']
#
# Processing period 1775-1799
# Training model for 1775-1799...
# Counting words and skipgrams...
# Total words: 33875
# Total skipgrams: 199570
# Building vocabulary...
# Vocabulary size: 1369
# Computing PPMI matrix...
# PPMI matrix shape: (1369, 1369)
# PPMI matrix non-zeros: 0
# Computing SVD...
# Singular values: [7.39595084e-09 7.33797423e-09 7.30744071e-09 7.28371010e-09
#  7.25312701e-09 7.22135395e-09 7.20455400e-09 7.18455319e-09
#  7.16981388e-09 7.16015782e-09]
# Final embeddings shape: (1369, 100)
# Embeddings non-zeros: 136900
# Min norm: 1.72001495036166e-05
# Max norm: 2.6979128475722997e-05
# Mean norm: 2.2087868625272913e-05
# Vocabulary size: 1369
# Sample words: ['the', 'and', 'have', 'that', 'which', 'with', 'for', 'our', 'will', 'they']
#
# Processing period 1850-1874
# Training model for 1850-1874...
# Counting words and skipgrams...
# Total words: 351722
# Total skipgrams: 2061155
# Building vocabulary...
# Vocabulary size: 1330
# Computing PPMI matrix...
# PPMI matrix shape: (1330, 1330)
# PPMI matrix non-zeros: 273
# Computing SVD...
# Singular values: [75.65067217 37.59078618 33.7358905  32.70561086 30.09475639 28.35921624
#  27.33432835 26.42898575 25.15792264 23.24299196]
# Final embeddings shape: (1330, 100)
# Embeddings non-zeros: 133000
# Min norm: 1.2272141119093094e-05
# Max norm: 5.357883230795377
# Mean norm: 0.11938532386619528
# Vocabulary size: 1330
# Sample words: ['the', 'and', 'that', 'have', 'for', 'this', 'which', 'not', 'states', 'with']
#
# Processing period 2025-2049
# Training model for 2025-2049...
# Counting words and skipgrams...
# Total words: 1858
# Total skipgrams: 9616
# Building vocabulary...
# Vocabulary size: 680
# Computing PPMI matrix...
# PPMI matrix shape: (680, 680)
# PPMI matrix non-zeros: 0
# Computing SVD...
# Singular values: [5.20116918e-09 5.18908580e-09 5.11632694e-09 5.08953299e-09
#  5.07970549e-09 5.05813140e-09 5.02220534e-09 5.01451631e-09
#  4.99257217e-09 4.96370952e-09]
# Final embeddings shape: (680, 100)
# Embeddings non-zeros: 68000
# Min norm: 2.0292924754568777e-05
# Max norm: 3.0673073752453854e-05
# Mean norm: 2.5513754828164737e-05
# Vocabulary size: 680
# Sample words: ['the', 'and', 'our', 'that', 'for', 'power', '’ve', 'america', 'you', 'people']
#
# Creating models for transcript texts...
#
# Processing period 1800-1824
# Training model for 1800-1824...
# Counting words and skipgrams...
# Total words: 100067
# Total skipgrams: 598756
# Building vocabulary...
# Vocabulary size: 1244
# Computing PPMI matrix...
# PPMI matrix shape: (1244, 1244)
# PPMI matrix non-zeros: 6
# Computing SVD...
# Singular values: [1.78965452e+01 5.75153929e+00 3.85025133e+00 6.98579801e-09
#  6.96678482e-09 6.95714425e-09 6.92058708e-09 6.90750681e-09
#  6.88045107e-09 6.86380186e-09]
# Final embeddings shape: (1244, 100)
# Embeddings non-zeros: 124400
# Min norm: 1.7658369058948772e-05
# Max norm: 3.408506916798571
# Mean norm: 0.0072523188271145615
# Vocabulary size: 1244
# Sample words: ['the', 'and', 'that', 'which', 'our', 'with', 'for', 'have', 'been', 'their']
#
# Processing period 1900-1924
# Training model for 1900-1924...
# Counting words and skipgrams...
# Total words: 367100
# Total skipgrams: 2157863
# Building vocabulary...
# Vocabulary size: 1318
# Computing PPMI matrix...
# PPMI matrix shape: (1318, 1318)
# PPMI matrix non-zeros: 6746
# Computing SVD...
# Singular values: [441.62021852  95.61281459  78.44351142  78.14116808  75.94146702
#   75.36485764  74.43130372  72.6209518   71.90393885  70.48851506]
# Final embeddings shape: (1318, 100)
# Embeddings non-zeros: 131800
# Min norm: 1.1180630747286278e-10
# Max norm: 7.349264707411251
# Mean norm: 0.6774190914753653
# Vocabulary size: 1318
# Sample words: ['the', 'and', 'that', 'for', 'which', 'with', 'our', 'this', 'have', 'not']
#
# Processing period 1975-1999
# Training model for 1975-1999...
# Counting words and skipgrams...
# Total words: 466193
# Total skipgrams: 2607791
# Building vocabulary...
# Vocabulary size: 1234
# Computing PPMI matrix...
# PPMI matrix shape: (1234, 1234)
# PPMI matrix non-zeros: 19942
# Computing SVD...
# Singular values: [825.6754467  122.14247437 116.92288385 109.62620141 107.49524322
#  106.68292951 105.78329336 105.49326143 103.84310043 102.40055606]
# Final embeddings shape: (1234, 100)
# Embeddings non-zeros: 123400
# Min norm: 9.056838519471063e-11
# Max norm: 7.028682884220201
# Mean norm: 1.1405961319906697
# Vocabulary size: 1234
# Sample words: ['the', 'and', 'that', 'our', 'for', 'have', 'this', 'will', 'with', 'you']
#
# Processing period 1825-1849
# Training model for 1825-1849...
# Counting words and skipgrams...
# Total words: 349187
# Total skipgrams: 2054830
# Building vocabulary...
# Vocabulary size: 1307
# Computing PPMI matrix...
# PPMI matrix shape: (1307, 1307)
# PPMI matrix non-zeros: 3245
# Computing SVD...
# Singular values: [309.51199339  82.59951675  67.59606752  64.60798832  62.971718
#   61.32669468  59.02185816  58.19180553  57.56845679  57.23787202]
# Final embeddings shape: (1307, 100)
# Embeddings non-zeros: 130700
# Min norm: 1.5342803989314942e-10
# Max norm: 8.546316521057088
# Mean norm: 0.48651816445863943
# Vocabulary size: 1307
# Sample words: ['the', 'and', 'that', 'which', 'for', 'with', 'our', 'have', 'been', 'this']
#
# Processing period 2000-2024
# Training model for 2000-2024...
# Counting words and skipgrams...
# Total words: 524172
# Total skipgrams: 2867291
# Building vocabulary...
# Vocabulary size: 1249
# Computing PPMI matrix...
# PPMI matrix shape: (1249, 1249)
# PPMI matrix non-zeros: 35042
# Computing SVD...
# Singular values: [1138.32173517  155.35307261  132.5974521   129.41528769  128.67707485
#   126.89048139  124.1617559   124.0490328   122.94533425  122.33401519]
# Final embeddings shape: (1249, 100)
# Embeddings non-zeros: 124900
# Min norm: 8.110042929995413e-11
# Max norm: 6.768307292052402
# Mean norm: 1.4084501038270583
# Vocabulary size: 1249
# Sample words: ['the', 'and', 'that', 'our', 'for', 'have', 'you', 'this', 'are', 'will']
#
# Processing period 1950-1974
# Training model for 1950-1974...
# Counting words and skipgrams...
# Total words: 445944
# Total skipgrams: 2451107
# Building vocabulary...
# Vocabulary size: 1254
# Computing PPMI matrix...
# PPMI matrix shape: (1254, 1254)
# PPMI matrix non-zeros: 11566
# Computing SVD...
# Singular values: [607.26251411 110.40877656 100.0216379   97.33458045  92.52662132
#   91.71252488  90.65524901  88.41315151  87.70209777  86.80712469]
# Final embeddings shape: (1254, 100)
# Embeddings non-zeros: 125400
# Min norm: 9.920358571484928e-11
# Max norm: 7.366868830943202
# Mean norm: 0.9167026453821887
# Vocabulary size: 1254
# Sample words: ['the', 'and', 'that', 'our', 'for', 'have', 'this', 'will', 'are', 'not']
#
# Processing period 1925-1949
# Training model for 1925-1949...
# Counting words and skipgrams...
# Total words: 240560
# Total skipgrams: 1352277
# Building vocabulary...
# Vocabulary size: 1295
# Computing PPMI matrix...
# PPMI matrix shape: (1295, 1295)
# PPMI matrix non-zeros: 521
# Computing SVD...
# Singular values: [108.06162555  40.42924195  39.5288412   34.64199757  33.22730664
#   32.17564026  31.67312924  31.33852201  30.04342451  29.52750365]
# Final embeddings shape: (1295, 100)
# Embeddings non-zeros: 129500
# Min norm: 1.0502937436931097e-05
# Max norm: 5.957287157402912
# Mean norm: 0.17730130846605924
# Vocabulary size: 1295
# Sample words: ['the', 'and', 'that', 'our', 'for', 'have', 'this', 'are', 'which', 'not']
#
# Processing period 1875-1899
# Training model for 1875-1899...
# Counting words and skipgrams...
# Total words: 397357
# Total skipgrams: 2329361
# Building vocabulary...
# Vocabulary size: 1290
# Computing PPMI matrix...
# PPMI matrix shape: (1290, 1290)
# PPMI matrix non-zeros: 4479
# Computing SVD...
# Singular values: [361.73779546  90.68048087  73.43752323  71.62367333  70.75240807
#   69.07304852  67.76122001  67.25880404  64.98641106  64.38097396]
# Final embeddings shape: (1290, 100)
# Embeddings non-zeros: 129000
# Min norm: 1.364968430223735e-10
# Max norm: 8.77725485079613
# Mean norm: 0.5876151204066931
# Vocabulary size: 1290
# Sample words: ['the', 'and', 'that', 'for', 'which', 'our', 'this', 'with', 'been', 'have']
#
# Processing period 1775-1799
# Training model for 1775-1799...
# Counting words and skipgrams...
# Total words: 34616
# Total skipgrams: 204011
# Building vocabulary...
# Vocabulary size: 1410
# Computing PPMI matrix...
# PPMI matrix shape: (1410, 1410)
# PPMI matrix non-zeros: 0
# Computing SVD...
# Singular values: [7.49294839e-09 7.47884027e-09 7.46038358e-09 7.41204048e-09
#  7.38526573e-09 7.38134788e-09 7.33865676e-09 7.33526860e-09
#  7.31602727e-09 7.29630355e-09]
# Final embeddings shape: (1410, 100)
# Embeddings non-zeros: 141000
# Min norm: 1.7474219043096e-05
# Max norm: 2.767063877370986e-05
# Mean norm: 2.1949343304258376e-05
# Vocabulary size: 1410
# Sample words: ['the', 'and', 'that', 'which', 'with', 'for', 'have', 'our', 'will', 'been']
#
# Processing period 1850-1874
# Training model for 1850-1874...
# Counting words and skipgrams...
# Total words: 359265
# Total skipgrams: 2106417
# Building vocabulary...
# Vocabulary size: 1308
# Computing PPMI matrix...
# PPMI matrix shape: (1308, 1308)
# PPMI matrix non-zeros: 2629
# Computing SVD...
# Singular values: [251.34196711  66.52199111  64.58387818  61.21180841  60.84740525
#   58.59320053  57.45802118  56.03240195  55.19533181  54.46874324]
# Final embeddings shape: (1308, 100)
# Embeddings non-zeros: 130800
# Min norm: 1.7573060775221646e-10
# Max norm: 6.886746571357501
# Mean norm: 0.43649916530565513
# Vocabulary size: 1308
# Sample words: ['the', 'and', 'that', 'for', 'this', 'which', 'not', 'with', 'have', 'from']
#
# Processing period 2025-2049
# Training model for 2025-2049...
# Counting words and skipgrams...
# Total words: 1897
# Total skipgrams: 9850
# Building vocabulary...
# Vocabulary size: 942
# Computing PPMI matrix...
# PPMI matrix shape: (942, 942)
# PPMI matrix non-zeros: 0
# Computing SVD...
# Singular values: [6.09461962e-09 6.08674982e-09 6.01109453e-09 6.00458690e-09
#  5.96877692e-09 5.95492450e-09 5.93659465e-09 5.92601594e-09
#  5.88311408e-09 5.87103279e-09]
# Final embeddings shape: (942, 100)
# Embeddings non-zeros: 94200
# Min norm: 1.9413426035872605e-05
# Max norm: 2.9631022246150487e-05
# Mean norm: 2.388482037443879e-05
# Vocabulary size: 942
# Sample words: ['the', 'and', 'our', 'that', 'for', 'but', 'you', 'power', 'from', 'it’s']

# %% [markdown]
# # Semantic shift
